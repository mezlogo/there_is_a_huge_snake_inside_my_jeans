# %% [markdown]
# # Welcome to first steps of analysis JN

# %% [markdown]
# ## Постановка задачи и выяснение общей картины.
# ### Цель этого проекта - анализ рынка труда по направленям Data Sciense и аналитики

# %%
# Common imports
import numpy as np
import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# %matplotlib inline

# from tqdm import tnrange, tqdm_notebook
# from random import random, randint

# from globals import path_to_dataset_folder

# to make this notebook's output stable across runs
np.random.seed(13)

print("Setup Complete!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-b7d465119c0c> in <module>
#       8 # from random import random, randint
#       9
# ---> 10 from globals import path_to_dataset_folder
#      11
#      12 # to make this notebook's output stable across runs
#
# ModuleNotFoundError: No module named 'globals'

# %% [markdown]
# ### Этап первый: получение данных
# #### Выгрузка собранного датасета

# %%
vacancies = pd.read_csv("/home/aleksey/PycharmProjects/My_Web_Scrapper/dataset/" + 'vacancies_data.csv', index_col=0).T
print("Data is ready!")
# Out:
# Data is ready!

# %%
# Посмотрим, что из себя представлет наш собранный датасет
vacancies.head()
# Out:
#                                     0                            1  \
# 0                      Data Scientist                ООО Артистраж
# 0.1                    Data Scientist                    ООО РАБЛЗ
# 0.2                    Data Scientist               ООО КИБЕРБОРЕЯ
# 0.3            Data Scientist (ML/CV)  ООО Искусственный интеллект
# 0.4  Data Scientist (Computer Vision)               СофтТелематика
#
#                                              2         3  \
# 0                                       Москва  1–3 года
# 0.1                                     Москва  1–3 года
# 0.2                                     Москва  1–3 года
# 0.3        Москва, 2-я Хуторская улица, 38Ас15  1–3 года
# 0.4  Савеловская, Москва, Вятская улица, 27с20   3–6 лет
#
#                                       4  \
# 0         Полная занятость, полный день
# 0.1  Полная занятость, удаленная работа
# 0.2       Полная занятость, полный день
# 0.3       Полная занятость, полный день
# 0.4     Полная занятость, гибкий график
#
#                                                 5  \
# 0    от 120 000 до 170 000 руб. до вычета налогов
# 0.1  от 150 000 до 210 000 руб. до вычета налогов
# 0.2  от 120 000 до 170 000 руб. до вычета налогов
# 0.3            от 180 000 до 200 000 руб. на руки
# 0.4             от 200 000 руб. до вычета налогов
#
#                                                  6  \
# 0    Вакансия опубликована 6 октября 2020 в Москве
# 0.1  Вакансия опубликована 4 октября 2020 в Москве
# 0.2  Вакансия опубликована 3 октября 2020 в Москве
# 0.3  Вакансия опубликована 5 октября 2020 в Москве
# 0.4  Вакансия опубликована 4 октября 2020 в Москве
#
#                                                      7  \
# 0    Обязанности:\nОбработка и аналитика входных да...
# 0.1  Наша компания разрабатывает аналитические реше...
# 0.2  Обязанности:\nОбработка и аналитика входных да...
# 0.3  Требования\nЗнание современных алгоритмов ML/D...
# 0.4  СофтТелематика — российский разработчик интелл...
#
#                                                      8
# 0    Python\nR\nMachine Learning\nComputer Vision\n...
# 0.1                   Data Mining\nPython\nSQL\nPandas
# 0.2  Python\nR\nGit\nMachine Learning\nМашинное обу...
# 0.3  Обучение и развитие\nC/C++\nPython 3\nNumPy\nT...
# 0.4   Data Analysis\nmachine learning\ncomputer vision

# %% [markdown]
# В целом, кусок собранного датасета выглядит вполне неплохо. Теперь надо бы привести его в адекватный вид. Зададим более осмысленные названия для столбцов. А также нормальные индексы для строк.

# %%
vacancies.columns = ['vacancy_title', 'company_name', 'location', 'required_experience', 'employment_mode', 'vacancy_salary',
              'published_date', 'vacancy_description', 'vacancy_tags']

# %%
vacancies.index = [idx for idx in range(1,vacancies.shape[0]+1)]

# %%
vacancies.head(5)
# Out:
#                       vacancy_title                 company_name  \
# 1                    Data Scientist                ООО Артистраж
# 2                    Data Scientist                    ООО РАБЛЗ
# 3                    Data Scientist               ООО КИБЕРБОРЕЯ
# 4            Data Scientist (ML/CV)  ООО Искусственный интеллект
# 5  Data Scientist (Computer Vision)               СофтТелематика
#
#                                     location required_experience  \
# 1                                     Москва            1–3 года
# 2                                     Москва            1–3 года
# 3                                     Москва            1–3 года
# 4        Москва, 2-я Хуторская улица, 38Ас15            1–3 года
# 5  Савеловская, Москва, Вятская улица, 27с20             3–6 лет
#
#                       employment_mode  \
# 1       Полная занятость, полный день
# 2  Полная занятость, удаленная работа
# 3       Полная занятость, полный день
# 4       Полная занятость, полный день
# 5     Полная занятость, гибкий график
#
#                                  vacancy_salary  \
# 1  от 120 000 до 170 000 руб. до вычета налогов
# 2  от 150 000 до 210 000 руб. до вычета налогов
# 3  от 120 000 до 170 000 руб. до вычета налогов
# 4            от 180 000 до 200 000 руб. на руки
# 5             от 200 000 руб. до вычета налогов
#
#                                   published_date  \
# 1  Вакансия опубликована 6 октября 2020 в Москве
# 2  Вакансия опубликована 4 октября 2020 в Москве
# 3  Вакансия опубликована 3 октября 2020 в Москве
# 4  Вакансия опубликована 5 октября 2020 в Москве
# 5  Вакансия опубликована 4 октября 2020 в Москве
#
#                                  vacancy_description  \
# 1  Обязанности:\nОбработка и аналитика входных да...
# 2  Наша компания разрабатывает аналитические реше...
# 3  Обязанности:\nОбработка и аналитика входных да...
# 4  Требования\nЗнание современных алгоритмов ML/D...
# 5  СофтТелематика — российский разработчик интелл...
#
#                                         vacancy_tags
# 1  Python\nR\nMachine Learning\nComputer Vision\n...
# 2                   Data Mining\nPython\nSQL\nPandas
# 3  Python\nR\nGit\nMachine Learning\nМашинное обу...
# 4  Обучение и развитие\nC/C++\nPython 3\nNumPy\nT...
# 5   Data Analysis\nmachine learning\ncomputer vision

# %% [markdown]
# Уже лучше. Но всё же есть ещё одна проблема - описание вакансий и тэги на данный момент являются цельными строками, без нормальной разметки. Исправим.

# %%
vacancies.vacancy_tags = vacancies.vacancy_tags.str.split(pat="\n")
vacancies.vacancy_description = vacancies.vacancy_description.str.split(pat="\n")
vacancies.head()
# Out:
#                       vacancy_title                 company_name  \
# 1                    Data Scientist                ООО Артистраж
# 2                    Data Scientist                    ООО РАБЛЗ
# 3                    Data Scientist               ООО КИБЕРБОРЕЯ
# 4            Data Scientist (ML/CV)  ООО Искусственный интеллект
# 5  Data Scientist (Computer Vision)               СофтТелематика
#
#                                     location required_experience  \
# 1                                     Москва            1–3 года
# 2                                     Москва            1–3 года
# 3                                     Москва            1–3 года
# 4        Москва, 2-я Хуторская улица, 38Ас15            1–3 года
# 5  Савеловская, Москва, Вятская улица, 27с20             3–6 лет
#
#                       employment_mode  \
# 1       Полная занятость, полный день
# 2  Полная занятость, удаленная работа
# 3       Полная занятость, полный день
# 4       Полная занятость, полный день
# 5     Полная занятость, гибкий график
#
#                                  vacancy_salary  \
# 1  от 120 000 до 170 000 руб. до вычета налогов
# 2  от 150 000 до 210 000 руб. до вычета налогов
# 3  от 120 000 до 170 000 руб. до вычета налогов
# 4            от 180 000 до 200 000 руб. на руки
# 5             от 200 000 руб. до вычета налогов
#
#                                   published_date  \
# 1  Вакансия опубликована 6 октября 2020 в Москве
# 2  Вакансия опубликована 4 октября 2020 в Москве
# 3  Вакансия опубликована 3 октября 2020 в Москве
# 4  Вакансия опубликована 5 октября 2020 в Москве
# 5  Вакансия опубликована 4 октября 2020 в Москве
#
#                                  vacancy_description  \
# 1  [Обязанности:, Обработка и аналитика входных д...
# 2  [Наша компания разрабатывает аналитические реш...
# 3  [Обязанности:, Обработка и аналитика входных д...
# 4  [Требования, Знание современных алгоритмов ML/...
# 5  [СофтТелематика — российский разработчик интел...
#
#                                         vacancy_tags
# 1  [Python, R, Machine Learning, Computer Vision,...
# 2                 [Data Mining, Python, SQL, Pandas]
# 3  [Python, R, Git, Machine Learning, Машинное об...
# 4  [Обучение и развитие, C/C++, Python 3, NumPy, ...
# 5  [Data Analysis, machine learning, computer vis...

# %% [markdown]
# Вот теперь намного лучше! С этим уже можно работать.
#
# Чтобы не испортить полученный датасет, сделаем его копию и работать далее будем с ней.

# %%
vacancies_df = vacancies.copy()

# %%
vacancies_df.head()
# Out:
#                       vacancy_title                 company_name  \
# 1                    Data Scientist                ООО Артистраж
# 2                    Data Scientist                    ООО РАБЛЗ
# 3                    Data Scientist               ООО КИБЕРБОРЕЯ
# 4            Data Scientist (ML/CV)  ООО Искусственный интеллект
# 5  Data Scientist (Computer Vision)               СофтТелематика
#
#                                     location required_experience  \
# 1                                     Москва            1–3 года
# 2                                     Москва            1–3 года
# 3                                     Москва            1–3 года
# 4        Москва, 2-я Хуторская улица, 38Ас15            1–3 года
# 5  Савеловская, Москва, Вятская улица, 27с20             3–6 лет
#
#                       employment_mode  \
# 1       Полная занятость, полный день
# 2  Полная занятость, удаленная работа
# 3       Полная занятость, полный день
# 4       Полная занятость, полный день
# 5     Полная занятость, гибкий график
#
#                                  vacancy_salary  \
# 1  от 120 000 до 170 000 руб. до вычета налогов
# 2  от 150 000 до 210 000 руб. до вычета налогов
# 3  от 120 000 до 170 000 руб. до вычета налогов
# 4            от 180 000 до 200 000 руб. на руки
# 5             от 200 000 руб. до вычета налогов
#
#                                   published_date  \
# 1  Вакансия опубликована 6 октября 2020 в Москве
# 2  Вакансия опубликована 4 октября 2020 в Москве
# 3  Вакансия опубликована 3 октября 2020 в Москве
# 4  Вакансия опубликована 5 октября 2020 в Москве
# 5  Вакансия опубликована 4 октября 2020 в Москве
#
#                                  vacancy_description  \
# 1  [Обязанности:, Обработка и аналитика входных д...
# 2  [Наша компания разрабатывает аналитические реш...
# 3  [Обязанности:, Обработка и аналитика входных д...
# 4  [Требования, Знание современных алгоритмов ML/...
# 5  [СофтТелематика — российский разработчик интел...
#
#                                         vacancy_tags
# 1  [Python, R, Machine Learning, Computer Vision,...
# 2                 [Data Mining, Python, SQL, Pandas]
# 3  [Python, R, Git, Machine Learning, Машинное об...
# 4  [Обучение и развитие, C/C++, Python 3, NumPy, ...
# 5  [Data Analysis, machine learning, computer vis...

# %%
# Посмотрим, что там у нас по зарплатам! 
vacancies_df.vacancy_salary.value_counts()
# Out:
# з/п не указана                                  146
# от 150 000 руб. на руки                           2
# от 120 000 до 170 000 руб. до вычета налогов      2
# от 120 000 до 160 000 руб. на руки                1
# от 180 000 до 200 000 руб. на руки                1
# от 200 000 руб. до вычета налогов                 1
# от 150 000 до 210 000 руб. до вычета налогов      1
# до 150 000 руб. на руки                           1
# до 100 000 руб. до вычета налогов                 1
# от 120 000 до 200 000 руб. на руки                1
# до 200 000 руб. на руки                           1
# от 200 000 до 280 000 руб. до вычета налогов      1
# до 500 000 руб. до вычета налогов                 1
# до 130 000 руб. до вычета налогов                 1
# от 120 000 до 150 000 руб. на руки                1
# Name: vacancy_salary, dtype: int64

# %% [markdown]
# Не густо - информации по зарплатам в явном виде исчезающе мало.
